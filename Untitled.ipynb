# %%
import pandas as pd
import sqlalchemy as alch
from getpass import getpass

# %%
rick_morty = pd.read_csv('./RickAndMortyScripts.csv')

# %%
rick_morty.head()
# Out:
#    index  season no.  episode no. episode name   name  \
# 0      0           1            1        Pilot   Rick
# 1      1           1            1        Pilot  Morty
# 2      2           1            1        Pilot   Rick
# 3      3           1            1        Pilot  Morty
# 4      4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
password = getpass("Introduce tu pass de sql: ")
dbName="rick_morty"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
print("me conecté")
# Out:
# Introduce tu pass de sql: ········
# me conecté

# %%
rick_morty['episode name'].unique()
# Out:
# array(['Pilot', 'Lawnmower Dog', 'Rick Potion 9', 'A Rickle in Time',
#        'The Wedding Squanchers', 'Get Schwifty',
#        'Interdimensional Cable 2  Tempting Fate',
#        'The Rickshank Rickdemption', 'Pickle Rick',
#        'Vindicators 3  The Return of Worldender',
#        'Tales From the Citadel'], dtype=object)

# %%
rick_morty.drop(['index'], axis = 1, inplace=True)

# %%
rick_morty.head()
# Out:
#    season no.  episode no. episode name   name  \
# 0           1            1        Pilot   Rick
# 1           1            1        Pilot  Morty
# 2           1            1        Pilot   Rick
# 3           1            1        Pilot  Morty
# 4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
rick_morty['season no.'].unique()
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### Solo quermeos a los personajes principales, es decir:
#
# - Rick
#
# - Morty
#
# - Jerry
#
# - Summer
#
# - Beth

# %%
rick_morty = rick_morty[(rick_morty['name'] == 'Rick') | (rick_morty['name'] == 'Morty') | (rick_morty['name'] == 'Jerry') | (rick_morty['name'] == 'Summer') | (rick_morty['name'] == 'Beth')]

# %%
rick_morty.name.unique()
# Out:
# array(['Rick', 'Morty', 'Jerry', 'Summer', 'Beth'], dtype=object)

# %%
# bien

# %% [markdown]
# Tengo que hacer ir por cada episodio y hacer depsues un try except para comprobar si cada personaje tiene mas de 10 frases, si tiene mas de 10, solo quiero que me devuelva 10, si tiene menos que me devuelva todas.

# %% [markdown]
# Creo que no es realmente importante hacer un data frame por cada uno de los episodios, que puedo hacer las llamadas directamnete con el daraframe original

# %% [markdown]
# Check function

# %%
def check (something, string):
    '''
    Checks if the value exists in the table.
    Args:
        something(str): the table from where we are checking
        string(str): a singular value of (something), the actual column
    Returns:
        bool: Ture if exists False if not exists
      
    '''
    if something == 'character':
        query = list(engine.execute(f"SELECT Character_name FROM `Character` WHERE Character_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif something == 'phrase':
        query = list(engine.execute(f"SELECT Phrase FROM `Phrase` WHERE Phrase = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif something == 'episode':
        query = list(engine.execute(f"SELECT Episode_name FROM Episode WHERE Episode_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False

# %% [markdown]
# Now we do functions to insert each value we want into the proper table in SQL

# %%
def insertCharacter (string):
    if check('character', string):
        return 'This character already exists'
    else:
        engine.execute(f"INSERT INTO `character` (Character_name) VALUES ('{string}');")

# %%
insertCharacter('Rick')
# Out:
# 'This character already exists'

# %%
insertCharacter('Morty')

# %%
insertCharacter('Beth')

# %%
def insertPhrase (string, n, m):
    if check('phrase', string):
        return 'This phrase already exists'
    else:
        engine.execute(f' INSERT INTO Phrase (Phrase, Character_idCharacter, Episode_idEpisode) VALUES ("{string}", {n}, {m});')

# %%
insertPhrase ("hola que pasa", 2, 1)

# %%
def insertEpisode (string):
    if check('episode', string):
        return 'This episode already exists'
    else:
        engine.execute(f' INSERT INTO Episode (Episode_name) VALUES ("{string}");')

# %%
insertEpisode('Pilot')

# %% [markdown]
# ITERROWS

# %%
for i, row in rick_morty.iterrows():
    engine.execute(f" INSERT INTO _ (_) VALUES ())

# %%
for i, fila in rick_morty.iterrows():
    if check('character', f"{fila['name']}"):
        print('This already exists')
    else:
        engine.execute(
            f"""
            INSERT INTO `character` (Character_name) VALUES
            ("{fila['name']}");
           """
        )
# Out:
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists

# %%
for i, fila in rick_morty.iterrows():
    if check ('episode', f"{fila['episode name']}"):
        print('This already exists')
    else:
        engine.execute(
            f"""
            INSERT INTO `episode` (Episode_name) VALUES
            ("{fila['episode name']}");
           """
        )
# Out:
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists

# %% [markdown]
# I need to make a dictionary for each character and for each episode, giving them, their correspond id. This is for making the INSERT query, this query needs the foreing keys, which are the ids of the characters and the ids of the episodes

# %%
characters = {
    'Rick' : 1,
    'Morty' : 2,
    'Jerry' : 3,
    'Summer' : 4,
    'Beth' : 5
}

# %%
episodes = {
    'Pilot' : 1,
    'Lawnmower Dog' : 2,
    'Rick Potion 9' : 3,
    'A Rickle in Time' : 4,
    'The Wedding Squanchers' : 5,
    'Get Schwifty' : 6,
    'Interdimensional Cable 2  Tempting Fate' : 7,
    'The Rickshank Rickdemption' : 8,
    'Pickle Rick' : 9,
    'Vindicators 3  The Return of Worldender' : 10,
    'Tales From the Citadel' : 11
}

# %% [markdown]
# ## Hago los string replaces necesarios para que no me den errores de SQL a la hora de leer

# %% [markdown]
# Los repalces son las comillas simples, las comillas dobles (estos dos me estaban cerrando las queries y dando errores por eso, hacemos un replace por espacio.
#
# El tercer error es el %, por el cual hacemos un replace por un doble porcentaje.

# %%
rick_morty.line = rick_morty.line.str.replace("'", ' ')

# %%
rick_morty.line = rick_morty.line.str.replace('"', ' ')

# %%
rick_morty.line = rick_morty.line.str.replace('%', '%%')

# %%
for ii, (i, fila) in enumerate(rick_morty.iterrows()):
    if ii % 100 == 0:
        print(f"voy por el {ii}")
    
    if check('phrase', f"{fila['line']}"):
        continue
        #print('This already exists')
    else:
        try:
            q = f"""
                INSERT INTO phrase (Phrase, Character_idCharacter, Episode_idEpisode) VALUES ("{fila['line']}", {characters[fila['name']]}, {episodes[fila['episode name']]});
                """
            engine.execute(q)            
        except:
            raise 'Couldn`t insert this phrase'
# Out:
# voy por el 0
# voy por el 100
# voy por el 200
# voy por el 300
# voy por el 400
# voy por el 500
# voy por el 600
# voy por el 700
# voy por el 800
# voy por el 900
# voy por el 1000
# voy por el 1100

# %% [markdown]
# ### Esto es el check que haremos para despues, para cuando hagamos los endpoints de tipo POST

# %%
def check2 (dictionary):
    for k,v in dictionary.items():
        if len(v) == 0:
            print(f'movida, dame {k}')

# %%
def check2 (dictionary):
    for k,v in dictionary.items():
        if len(v) == 0:
            print(f'movida, dame {k}')
    if k == 'character':
        query = list(engine.execute(f"SELECT Character_name FROM `Character` WHERE Character_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif k == 'phrase':
        query = list(engine.execute(f"SELECT Phrase FROM `Phrase` WHERE Phrase = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif k == 'episode':
        query = list(engine.execute(f"SELECT Episode_name FROM Episode WHERE Episode_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False

# %%
def insert(dictionary):
    for k,v in dictionary.items():
        if k == 'character':
            if check('character', string):
            return 'This character already exists'
        else:
            engine.execute(f"INSERT INTO `character` (Character_name) VALUES ('{string}');")

# %%
def character_phrases(name):
    query = f"""
    SELECT `character`.Character_name, `phrase`.phrase
    FROM `character`
    INNER JOIN `phrase`
    ON `character`.idCharacter = phrase.Character_idCharacter
    WHERE Character_name = '{name}';

    """
    datos = pd.read_sql_query(query,engine)
    return datos.to_json(orient='records')

# %%
#character_phrases("Beth") # funciona

# %% [markdown]
# No se que estoy haciendo

# %% [markdown]
# ### ENDPOINTS

# %%
from flask import Flask, request
from flask import json
from flask.json import jsonify, load
from numpy import character
from sqlalchemy.util.langhelpers import method_is_overridden

# %%
dict_ = {
    'saludo' : '',
    'trabajo' : 'data'
    
}

# %%
if len(dict_["saludo"]) == 0:
    print("lo siento pa tu casa")

# %%
for k,v in dict_.items():
    if len(v) == 0:
        print(f'movida, dame {k}')
# Out:
# movida, dame saludo

# %%
dict_['saludo']
# Out:
# 'que pasa'

# %%
def episode_divider(df,n):
    '''
    Me corta el df original y lo divide por el episodio que quiera
    Args:
        df(pd.DataFrame): el dataframe que quiero recortar
        n(int): el numero de episodio que quiero filtrar
    Returns:
        pd.DataFrame
    
    '''
    df = df[df['episode no.'] == n]
    return df

# %%
#d = {}
#for i in len(range(1,11)):
    #d = ['ep_{0}'.format(i)] = episode_divider(rick_morty,i)

# %%
# y si hago u groupby y de esta manera se me analizan todas las frases de cada personaje en cada episodio?
# es decir, sumo los strings de cada personaje de cada dialogo y me analizara todo

# %%
def sum_lines (df):
    df = df.groupby('name').agg({'line' : 'sum'})
    return df.reset_index()

# %%
grouped_1 = sum_lines(ep_1)

# %%
grouped_1
# Out:
#      name                                               line
# 0    Beth  Morty, are you getting sick?  I told you not t...
# 1   Jerry  I see there's a new episode of that singing sh...
# 2   Morty  What, Rick? What’s going on?It's the middle of...
# 3    Rick  Morty! You gotta come on. Jus'... you gotta co...
# 4  Summer  Oh my God, his head is in his food. I'm going ...

# %%
grouped_2 = sum_lines(ep_2)

# %%
# puedo hacer el agrupado y el episode divider todo a la vez?, seguramente si

# %%
# tengo que añadir aun asi la columna de episodio en cada uno, pese a que cada tabla sera un episodio por si solo

# %%
# generar un dataframe con los nombres de lo episidios, porque esto es algo que tenemos que agregar a la base de datos
# y eventualmente devolvermo como endpoint en nuestra API
