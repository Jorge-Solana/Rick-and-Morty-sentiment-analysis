# %%
import pandas as pd
import sqlalchemy as alch
from getpass import getpass

# %%
rick_morty = pd.read_csv('./RickAndMortyScripts.csv')

# %%
rick_morty.head()
# Out:
#    index  season no.  episode no. episode name   name  \
# 0      0           1            1        Pilot   Rick
# 1      1           1            1        Pilot  Morty
# 2      2           1            1        Pilot   Rick
# 3      3           1            1        Pilot  Morty
# 4      4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
password = getpass("Introduce tu pass de sql: ")
dbName="rick_morty"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
print("me conecté")
# Out:
# Introduce tu pass de sql: ········
# me conecté

# %%
rick_morty.drop(['index'], axis = 1, inplace=True)

# %%
rick_morty.head()
# Out:
#    season no.  episode no. episode name   name  \
# 0           1            1        Pilot   Rick
# 1           1            1        Pilot  Morty
# 2           1            1        Pilot   Rick
# 3           1            1        Pilot  Morty
# 4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %% [markdown]
# ### Solo quermeos a los personajes principales, es decir:
#
# - Rick
#
# - Morty
#
# - Jerry
#
# - Summer
#
# - Beth

# %%
rick_morty = rick_morty[(rick_morty['name'] == 'Rick') | (rick_morty['name'] == 'Morty') | (rick_morty['name'] == 'Jerry') | (rick_morty['name'] == 'Summer') | (rick_morty['name'] == 'Beth')]

# %% [markdown]
# Tengo que hacer ir por cada episodio y hacer depsues un try except para comprobar si cada personaje tiene mas de 10 frases, si tiene mas de 10, solo quiero que me devuelva 10, si tiene menos que me devuelva todas.

# %% [markdown]
# Creo que no es realmente importante hacer un data frame por cada uno de los episodios, que puedo hacer las llamadas directamnete con el daraframe original

# %% [markdown]
# Check function

# %%
def check (something, string):
    '''
    Checks if the value exists in the table.
    Args:
        something(str): the table from where we are checking
        string(str): a singular value of (something), the actual column
    Returns:
        bool: Ture if exists False if not exists
      
    '''
    if something == 'character':
        query = list(engine.execute(f"SELECT Character_name FROM `Character` WHERE Character_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif something == 'phrase':
        query = list(engine.execute(f"SELECT Phrase FROM `Phrase` WHERE Phrase = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif something == 'episode':
        query = list(engine.execute(f"SELECT Episode_name FROM Episode WHERE Episode_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False

# %% [markdown]
# Now we do functions to insert each value we want into the proper table in SQL

# %%
def insertCharacter (string):
    if check('character', string):
        return 'This character already exists'
    else:
        engine.execute(f"INSERT INTO `character` (Character_name) VALUES ('{string}');")

# %%
insertCharacter('Rick')
# Out:
# 'This character already exists'

# %%
insertCharacter('Morty')

# %%
insertCharacter('Beth')

# %%
def insertPhrase (string, n, m):
    if check('phrase', string):
        return 'This phrase already exists'
    else:
        engine.execute(f' INSERT INTO Phrase (Phrase, Character_idCharacter, Episode_idEpisode) VALUES ("{string}", {n}, {m});')

# %%
insertPhrase ("hola que pasa", 2, 1)

# %%
def insertEpisode (string):
    if check('episode', string):
        return 'This episode already exists'
    else:
        engine.execute(f' INSERT INTO Episode (Episode_name) VALUES ("{string}");')

# %%
insertEpisode('Pilot')

# %% [markdown]
# ITERROWS

# %%
for i, fila in rick_morty.iterrows():
    if check('character', f"{fila['name']}"):
        print('This already exists')
    else:
        engine.execute(
            f"""
            INSERT INTO `character` (Character_name) VALUES
            ("{fila['name']}");
           """
        )
# Out:
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# ...

# %%
for i, fila in rick_morty.iterrows():
    if check ('episode', f"{fila['episode name']}"):
        print('This already exists')
    else:
        engine.execute(
            f"""
            INSERT INTO `episode` (Episode_name) VALUES
            ("{fila['episode name']}");
           """
        )
# Out:
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# This already exists
# ...

# %% [markdown]
# I need to make a dictionary for each character and for each episode, giving them, their correspond id. This is for making the INSERT query, this query needs the foreing keys, which are the ids of the characters and the ids of the episodes

# %%
characters = {
    'Rick' : 1,
    'Morty' : 2,
    'Jerry' : 3,
    'Summer' : 4,
    'Beth' : 5
}

# %%
episodes = {
    'Pilot' : 1,
    'Lawnmower Dog' : 2,
    'Rick Potion 9' : 3,
    'A Rickle in Time' : 4,
    'The Wedding Squanchers' : 5,
    'Get Schwifty' : 6,
    'Interdimensional Cable 2  Tempting Fate' : 7,
    'The Rickshank Rickdemption' : 8,
    'Pickle Rick' : 9,
    'Vindicators 3  The Return of Worldender' : 10,
    'Tales From the Citadel' : 11
}

# %% [markdown]
# ## Hago los string replaces necesarios para que no me den errores de SQL a la hora de leer

# %% [markdown]
# Los repalces son las comillas simples, las comillas dobles (estos dos me estaban cerrando las queries y dando errores por eso, hacemos un replace por espacio.
#
# El tercer error es el %, por el cual hacemos un replace por un doble porcentaje.

# %%
rick_morty.line = rick_morty.line.str.replace("'", ' ')

# %%
rick_morty.line = rick_morty.line.str.replace('"', ' ')

# %%
rick_morty.line = rick_morty.line.str.replace('%', '%%')

# %%
for ii, (i, fila) in enumerate(rick_morty.iterrows()):
    if ii % 100 == 0:
        print(f"voy por el {ii}")
    
    if check('phrase', f"{fila['line']}"):
        continue
    else:
        try:
            q = f"""
                INSERT INTO phrase (Phrase, Character_idCharacter, Episode_idEpisode) VALUES ("{fila['line']}", {characters[fila['name']]}, {episodes[fila['episode name']]});
                """
            engine.execute(q)            
        except:
            raise 'Couldn`t insert this phrase'
# Out:
# voy por el 0
# voy por el 100
# voy por el 200
# voy por el 300
# voy por el 400
# voy por el 500
# voy por el 600
# voy por el 700
# voy por el 800
# voy por el 900
# voy por el 1000
# voy por el 1100

# %% [markdown]
# ### Esto es el check que haremos para despues, para cuando hagamos los endpoints de tipo POST

# %%
data = {
    'character' : 'Pepe',
    'Phrase' : 'Hola que pasa',
    'Episode' : 'El episodio molon'
    
}

# %%
def insert_data(data):
    engine.execute(f"""
    INSERT INTO `character` (Chracter_name)
    VALUES ({data['character']});
    INSERT INTO `phrase` (Phrase)
    VALUES ({data['phrase']});
    INSERT INTO episode (Episode_name)
    VALUES ({data['episode']});
    """)
    return 'The data was inserted correctly'

# %%
insert_data(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-7376bdafb47c> in <module>
# ----> 1 insert_data(data)
#
# <ipython-input-12-7c18e34e5e1d> in insert_data(data)
#       4     VALUES ({data['character']});
#       5     INSERT INTO `phrase` (Phrase)
# ----> 6     VALUES ({data['phrase']});
#       7     INSERT INTO episode (Episode_name)
#       8     VALUES ({data['episode']});
#
# KeyError: 'phrase'

# %%
def check2 (dictionary):
    for k,v in dictionary.items():
        if len(v) == 0:
            print(f'movida, dame {k}')

# %%
def check2 (dictionary):
    for k,v in dictionary.items():
        if len(v) == 0:
            print(f'movida, dame {k}')
    if k == 'character':
        query = list(engine.execute(f"SELECT Character_name FROM `Character` WHERE Character_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif k == 'phrase':
        query = list(engine.execute(f"SELECT Phrase FROM `Phrase` WHERE Phrase = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False
    elif k == 'episode':
        query = list(engine.execute(f"SELECT Episode_name FROM Episode WHERE Episode_name = '{string}'" ))
        if len(query) > 0:
            return True
        else:
            return False

# %%
def insert(dictionary):
    for k,v in dictionary.items():
        if k == 'character':
            if check2('character', string):
                return 'This character already exists'
            else:
                engine.execute(f"""
                INSERT INTO `character` (Character_name) VALUES ('{string}');
                """)
        
        elif k == 'phrase':
            if check2('phrase', string):
                return 'This phrase already exists'
            else:
                engine.execute(f"""
                INSERT INTO `phrase` (Phrase) VALUES ('{string}');
                """)
        
        elif k == 'episode':
            if check2('episode', string):
                return 'This episode already exists'
            else:
                engine.execute(f"""
                INSERT INTO episode (Episode_name) VALUES ('{string}');
                """)

# %%
def character_phrases(name):
    query = f"""
    SELECT `character`.Character_name, `phrase`.phrase
    FROM `character`
    INNER JOIN `phrase`
    ON `character`.idCharacter = phrase.Character_idCharacter
    WHERE Character_name = '{name}';

    """
    datos = pd.read_sql_query(query,engine)
    return datos.to_json(orient='records')

# %% [markdown]
# ### ENDPOINTS

# %%
from flask import Flask, request
from flask import json
from flask.json import jsonify, load
from numpy import character
from sqlalchemy.util.langhelpers import method_is_overridden

# %%
dict_ = {
    'saludo' : '',
    'trabajo' : 'data'
    
}

# %%
if len(dict_["saludo"]) == 0:
    print("lo siento pa tu casa")

# %%
for k,v in dict_.items():
    if len(v) == 0:
        print(f'movida, dame {k}')
# Out:
# movida, dame saludo

# %% [markdown]
# ### NLP

# %%
import string
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
from nltk.corpus import stopwords

# %%
test = 'Hi, I am looking at the round table '

# %%
test_nlp = nlp(test)

# %%
test_nlp
# Out:
# Hi, I am looking at the round table

# %%
type(test)
# Out:
# str

# %%
type(test_nlp)
# Out:
# spacy.tokens.doc.Doc

# %%
stop = nlp.Defaults.stop_words

# %%
test_nlp[5].is_stop
# Out:
# True

# %%
rick_morty.head()
# Out:
#    season no.  episode no. episode name   name  \
# 0           1            1        Pilot   Rick
# 1           1            1        Pilot  Morty
# 2           1            1        Pilot   Rick
# 3           1            1        Pilot  Morty
# 4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus ... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It s the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
rick_morty.loc[0]['line']
# Out:
# 'Morty! You gotta come on. Jus ... you gotta come with me.'

# %%
import requests

# %%
url = 'http://127.0.0.1:5000/'

# %%
data = requests.get(url)

# %%
data.content
# Out:
# b'Que pasa con tu rollo repollo'

# %%
data1 = requests.get('http://127.0.0.1:5000/phrases')

# %%
df = pd.DataFrame(data1.json())

# %%
df.head()
# Out:
#    idPhrase                                             Phrase  \
# 0         1  Morty! You gotta come on. Jus ... you gotta co...
# 1         2                       What, Rick? What’s going on?
# 2         3                   I got a surprise for you, Morty.
# 3         4  It s the middle of the night. What are you tal...
# 4         5  Come on, I got a surprise for you.  Come on, h...
#
#    Character_idCharacter  Episode_idEpisode
# 0                      1                  1
# 1                      2                  1
# 2                      1                  1
# 3                      2                  1
# 4                      1                  1

# %%
df['Phrase']
# Out:
# 0       Morty! You gotta come on. Jus ... you gotta co...
# 1                            What, Rick? What’s going on?
# 2                        I got a surprise for you, Morty.
# 3       It s the middle of the night. What are you tal...
# 4       Come on, I got a surprise for you.  Come on, h...
#                               ...
# 1115                                    That was amazing!
# 1116                       Got some of that mermaid puss!
# 1117    I m really hoping it wasn t a one-off thing an...
# 1118    Pssh! Not at all, Morty. That place will never...
# 1119                       Whoo! Yeah! Yeaah! Ohhh, shit!
# Name: Phrase, Length: 1120, dtype: object

# %%
data2 = requests.get('http://127.0.0.1:5000/phrases/Morty')

# %%
df2 = pd.DataFrame(data2.json())

# %%
df2.head()
# Out:
#   Character_name                                             phrase
# 0          Morty                       What, Rick? What’s going on?
# 1          Morty  It s the middle of the night. What are you tal...
# 2          Morty                Ow! Ow! You re tugging me too hard!
# 3          Morty  Yeah, Rick... I-it s great. Is this the surprise?
# 4          Morty                                    What?! A bomb?!

# %%
df2['phrase']
# Out:
# 0                           What, Rick? What’s going on?
# 1      It s the middle of the night. What are you tal...
# 2                    Ow! Ow! You re tugging me too hard!
# 3      Yeah, Rick... I-it s great. Is this the surprise?
# 4                                        What?! A bomb?!
#                              ...
# 325                                    Mortys are human!
# 326                                               WHOA!!
# 327                                    That was amazing!
# 328    I m really hoping it wasn t a one-off thing an...
# 329                       Whoo! Yeah! Yeaah! Ohhh, shit!
# Name: phrase, Length: 330, dtype: object

# %%
blob2 = TextBlob(df2.loc[0]['phrase'])
blob2.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
for i in df2['phrase']:
    pol = TextBlob(df2.loc[i]['phrase'])
    sentiment = pol.sentiment[0]
# Out:
#   File "<ipython-input-149-84981c3b3904>", line 2
#     pol = TextBlob(df2.loc[i]['phrase'])
#     ^
# IndentationError: unexpected indent

# %%
df2.head()
# Out:
#   Character_name                                             phrase
# 0          Morty                       What, Rick? What’s going on?
# 1          Morty  It s the middle of the night. What are you tal...
# 2          Morty                Ow! Ow! You re tugging me too hard!
# 3          Morty  Yeah, Rick... I-it s great. Is this the surprise?
# 4          Morty                                    What?! A bomb?!

# %% [markdown]
# ### Sentiment analysis

# %%
from textblob import TextBlob

# %%
blob = TextBlob('you smell bad')
blob.sentiment
# Out:
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)

# %%
blob2 = TextBlob(df2.loc[2]['phrase'])
blob2.sentiment
# Out:
# Sentiment(polarity=-0.36458333333333337, subjectivity=0.5416666666666666)

# %%
def character_sentiment(name):
    data = requests.get(f'http://127.0.0.1:5000/phrases/{name}')
    df = pd.DataFrame(data.json())
    #print(df)
    for i,row in df.iterrows():
        blob = TextBlob(f"{row['phrase']}")
        polarity = blob.sentiment[0]
    return polarity

# %%
character_sentiment("Morty")
# Out:
# -0.25

# %%
character_sentiment('Rick')
# Out:
# -0.15625

# %%
character_sentiment('Summer')
# Out:
# 0.0

# %%
character_sentiment('Jerry')
# Out:
# 0.0

# %%
character_sentiment('Beth')
# Out:
# -0.1875

# %%
# lets try now a function for the polarity of the episodes

# %%
import ast
import json

# %%
def phrases_episode(episode):
    '''
    Calls the database and returns all the phrases of the specified episode
    Args:
        episode(str): the name of the episode
    Returns:
        json: all the phrases of an episode in a json format
    
    '''
    query = f"""
    SELECT episode.Episode_name, `phrase`.phrase
    FROM episode
    INNER JOIN `phrase`
    ON episode.idEpisode = `phrase`.Episode_idEpisode
    WHERE Episode_name = "{episode}";
    
    """
    datos = pd.read_sql_query(query,engine)
    str_ = datos.to_json(orient='records')
    return ast.literal_eval(str_)

# %%
si = phrases_episode('Pilot')

# %%
si
# Out:
# [{'Episode_name': 'Pilot',
#   'phrase': 'Morty! You gotta come on. Jus ... you gotta come with me.'},
#  {'Episode_name': 'Pilot', 'phrase': 'What, Rick? What’s going on?'},
#  {'Episode_name': 'Pilot', 'phrase': 'I got a surprise for you, Morty.'},
#  {'Episode_name': 'Pilot',
#   'phrase': 'It s the middle of the night. What are you talking about?'},
#  {'Episode_name': 'Pilot',
#   'phrase': 'Come on, I got a surprise for you.  Come on, hurry up.'},
#  {'Episode_name': 'Pilot', 'phrase': 'Ow! Ow! You re tugging me too hard!'},
#  {'Episode_name': 'Pilot',
#   'phrase': 'We gotta go, gotta get outta here, come on. Got a surprise for you Morty.'},
#  {'Episode_name': 'Pilot',
#   'phrase': 'What do you think of this... flying vehicle, Morty? I built it outta stuff I found in the garage.'},
#  {'Episode_name': 'Pilot',
#   'phrase': 'Yeah, Rick... I-it s great. Is this the surprise?'},
#  {'Episode_name': 'Pilot',
# ...

# %%
df_hola = pd.DataFrame(si)

# %%
df_hola.head()
# Out:
#   Episode_name                                             phrase
# 0        Pilot  Morty! You gotta come on. Jus ... you gotta co...
# 1        Pilot                       What, Rick? What’s going on?
# 2        Pilot                   I got a surprise for you, Morty.
# 3        Pilot  It s the middle of the night. What are you tal...
# 4        Pilot  Come on, I got a surprise for you.  Come on, h...

# %%
def conjunta(episode):
    query = phrases_episode(f'{episode}')
    df = pd.DataFrame(query)
    all_ = []
    for i, row in df.iterrows():
        blob = TextBlob(f"{row['phrase']}")
        pol = blob.sentiment[0]
        all_.append(pol)
    return sum(all_)/len(all_)

# %%
conjunta('Pilot')
# Out:
# 0.055224589253938944

# %%
conjunta('Rick Potion 9')
# Out:
# 0.12013266417678181

# %%
data_ = requests.get('http://127.0.0.1:5000/phrases/Pilot')

# %%
data_
# Out:
# <Response [200]>

# %%
data_.json()
# Out:
# []

# %%
def episode_sentiment(ep_name):
    #here the name is the name of the episode
    data = requests.get(f'http://127.0.0.1:5000/phrases/{ep_name}')
    df = pd.DataFrame(data.json())
    print(df)
    for i,row in df.iterrows():
        blob = TextBlob(f"{row['phrase']}")
        polarity = blob.sentiment[0]
    return polarity

# %%
episode_sentiment('Pilot')
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-38-24da92b723dc> in <module>
# ----> 1 episode_sentiment('Pilot')
#
# <ipython-input-37-4623e61f49c9> in episode_sentiment(ep_name)
#       7         blob = TextBlob(f"{row['phrase']}")
#       8         pol = blob.sentiment[0]
# ----> 9     return pol
#
# UnboundLocalError: local variable 'pol' referenced before assignment

# %%
# the general sentiment of the season 1

# %%
def general_sentiment():
    data_ = requests.get('http://127.0.0.1:5000/phrases')
    df = pd.DataFrame(data_.json())
    list_ = []
    for i, row in df.iterrows():
        blob = TextBlob(f'{row["Phrase"]}')
        polarity_ = blob.sentiment[0]
        list_.append(polarity_)
    return sum(list_)/len(list_)

# %%
general_sentiment()
# Out:
# 0.04426021875353562
